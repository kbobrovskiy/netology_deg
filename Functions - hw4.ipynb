# %%
#q - выход
#p - владелец документа
#s - по номеру документа узнать на какой полке он хранится
#/ - полную информацию по всем документам
#ads - добавить новую полку
#ds - удалить существующую полку из данных (только если она пустая)
documents = [
 {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
 {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
 {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
directories = {
 '1': ['2207 876234', '11-2'],
 '2': ['10006'],
 '3': []
}

def docowner():
    doc_num = input('Введите номер документа')
    owner_name = [el.get("name") for el in documents if el["number"] == doc_num]
    if len(owner_name) == 0:
        print('Документ не найден')
    else: print(f'Владелец документа: {owner_name[0]}')
    return None

def docdir(p_doc_num = None):
    if p_doc_num is None:
        doc_num = input('Введите номер документа')
    else:
        doc_num = p_doc_num
    dir_num = [k for k, i in directories.items() if doc_num in i]
    if p_doc_num is None:
        if len(dir_num) == 0:
            print('Документ не найден')
        else: print(f'Документ хранится на полке: {dir_num[0]}')
        return None
    else: return dir_num[0]

def allinfo():
    for el in documents:
        print(f'№: {el["number"]}, тип: {el["type"]}, владелец: {el["name"]}, полка хранения: {docdir(el["number"])}')
    return None

def add_dir():
    new_dir = input('Введите номер полки')
    x = directories.setdefault(new_dir, [])
    if x is None:
        print(f'Полка добавлена. Текущий перечень полок: {", ".join(sorted(directories))}')
    else: print(f'Такая полка уже существует. Текущий перечень полок: {", ".join(sorted(directories))}')
    return None

def rem_dir():
    rm_dir = input('Введите номер полки')
    if rm_dir not in directories.keys(): 
        print(f'Такой полки не существует. Текущий перечень полок: {", ".join(sorted(directories))}')
    elif len(directories[rm_dir]) > 0:
        print(f'На полке есть документа, удалите их перед удалением полки. Текущий перечень полок: {", ".join(sorted(directories))}')
    else:
        directories.pop(rm_dir)
        print(f'Полка удалена. Текущий перечень полок: {", ".join(sorted(directories))}')
    return None
    

def main():
    while True:
        cmd = input('Введите команду:')
        if cmd.lower() == 'q':
            break
        elif cmd.lower() == 'p':
            docowner()
        elif cmd.lower() == 's':
            docdir()
        elif cmd.lower() == '/':
            allinfo()
        elif cmd.lower() == 'ads':
            add_dir()
        elif cmd.lower() == 'ds':
            rem_dir()
        
main()
# Out:
# Введите команду:ads
# Введите номер полки7
# Такая полка уже существует. Текущий перечень полок: 1, 2, 3, 7
# Введите команду:ads
# Введите номер полки5
# Такая полка уже существует. Текущий перечень полок: 1, 2, 3, 5, 7
# Введите команду:ds
# Введите номер полки5
# Полка удалена. Текущий перечень полок: 1, 2, 3, 7
# Введите команду:q
